# %%
#  Athletes 	Disciple/Sport 
import pandas as pd 
import matplotlib.pyplot as plt

# Extract the data we're interested in
olympian = pd.read_csv('Olympics_CSV.csv')
olympian.head()
# Out:
#                   Countries  Number of medals  Number of Athletes  \
# 0                 Venezuela                 4                  43
# 1                Uzbekistan                 3                  63
# 2  United States of America                77                 615
# 3                   Ukraine                11                 152
# 4                    Uganda                 3                  24
#
#    Count of Discipline/Sport
# 0                         10
# 1                          2
# 2                         28
# 3                          4
# 4                          2

# %%
# Extract the data we're interested in
olympian = pd.read_csv('Olympics_CSV.csv')
medals = olympian['Number of medals']
athletesData = olympian['Number of Athletes']
disciplineSportData = olympian['Count of Discipline/Sport']


#To plot the graph with grid, title, legend  
plt.plot(medals, athletesData, label = 'facecream', color = 'k', linestyle = 'dotted', linewidth = 3)
plt.plot(medals, disciplineSportData, label = 'facewash', color = 'b', linestyle = '--', linewidth = 3)

plt.grid()
plt.xlabel('Variables in Olympics')
plt.ylabel('Number of Medals')
plt.legend(loc = 'upper left',framealpha=1, frameon=True);
plt.title('All Variables Displayed')
# Out:
# Text(0.5, 1.0, 'All Variables Displayed')

# %%
# Extract the data we're interested in
olympian = pd.read_csv('Olympics_CSV.csv')
medals,athletes = olympian['Number of medals'], olympian['Number of Athletes']
#plt.axis(aspect='equal')
plt.scatter(medals, athletes)
plt.grid()
plt.xlabel('Number of Athletes')
plt.ylabel('Number of medals')
plt.title('Medals of Athletes per country ')
# Out:
# Text(0.5, 1.0, 'Medals of Athletes per country ')

# %%
# Extract the data we're interested in
olympian = pd.read_csv('Olympics_CSV.csv')
medals,discipline = olympian['Number of medals'], olympian['Count of Discipline/Sport']
#plt.axis(aspect='equal')
plt.scatter(medals, discipline)
plt.grid()
plt.xlabel('Count of Discipline/Sport')
plt.ylabel('Number of medals')
plt.title('Medals based on Discipline per country ')
# Out:
# Text(0.5, 1.0, 'Medals based on Discipline per country ')

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import style

#Load in data set 
df = pd.read_csv('Linear Regression for Medals & Athletes.csv')
df.head()
# Out:
#    Number of medals  Number of Athletes
# 0                 4                  43
# 1                 3                  63
# 2                77                 615
# 3                11                 152
# 4                 3                  24

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import style
from sklearn import linear_model

#Convert Medals and Athletes to columns 
athletes_list = df['Number of Athletes'].tolist()
medals_list = df['Number of medals'].tolist()

#convert lists to numpy lists
x = np.array(athletes_list,dtype = np.float64)
y = np.array(medals_list,dtype = np.float64)

#Create Linear regression object 
medals_athletes = linear_model.LinearRegression()

#Train the model using the training sets
medals_athletes.fit(x.reshape(-1,1),y)

#get the regression line using the model 
regression_line = medals_athletes.predict(x.reshape(-1,1))


#plot points 
style.use('seaborn')
plt.scatter(x, y, label = 'Data Points', alpha = 0.6, color = 'g', s = 75 )
plt.plot(x, regression_line, label = 'Best Fit Line', color = 'orange', linewidth = 4)
plt.xlabel('Number of Athletes')
plt.ylabel('Number of Medals')
plt.legend()

# %%
#Display the cooefficients and intercept 
print(medals_athletes.coef_)
# Out:
# [0.09280544]

# %%
print(medals_athletes.intercept_)
# Out:
# -1.9334624533639406

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import style
from sklearn import linear_model

#Load in data set 
df = pd.read_csv('Linear Regression for Medals and DisciplineSport.csv')
df.head()
# Out:
#    Number of medals  Count of Discipline/Sport
# 0                 4                         10
# 1                 3                          2
# 2                77                         28
# 3                11                          4
# 4                 3                          2

# %%
#Convert Medals and Athletes to columns 
DisciplineSport_list = df['Count of Discipline/Sport'].tolist()
medals_list = df['Number of medals'].tolist()

#convert lists to numpy lists
x = np.array(DisciplineSport_list,dtype = np.float64)
y = np.array(medals_list,dtype = np.float64)

#Create Linear regression object 
medals_DisciplineSport = linear_model.LinearRegression()

#Train the model using the training sets
medals_DisciplineSport.fit(x.reshape(-1,1),y)

#get the regression line using the model 
regression_line = medals_DisciplineSport.predict(x.reshape(-1,1))


#plot points 
style.use('seaborn')
plt.scatter(x, y, label = 'Data Points', alpha = 0.6, color = 'g', s = 75 )
plt.plot(x, regression_line, label = 'Best Fit Line', color = 'orange', linewidth = 4)
plt.xlabel('Number of Discipline/Sport')
plt.ylabel('Number of Medals')
plt.legend()

# %%
#Display the cooefficients and intercept 
print(medals_DisciplineSport.coef_)
# Out:
# [1.53558966]

# %%
print(medals_DisciplineSport.intercept_)
# Out:
# 1.3510447512199182

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import style

#Load in data set 
df = pd.read_csv('Linear Regression for Medals and Teams .csv')
df.head()
# Out:
#    Number of medals  Number of Teams
# 0                 4                 1
# 1                 3                 1
# 2                77                47
# 3                11                10
# 4                 3                24

# %%
#Convert Medals and Athletes to columns 
Teams_list = df['Number of Teams '].tolist()
medals_list = df['Number of medals'].tolist()

#convert lists to numpy lists
x = np.array(Teams_list,dtype = np.float64)
y = np.array(medals_list,dtype = np.float64)

#Create Linear regression object 
medals_Teams = linear_model.LinearRegression()

#Train the model using the training sets
medals_Teams.fit(x.reshape(-1,1),y)

#get the regression line using the model 
regression_line = medals_Teams.predict(x.reshape(-1,1))


#plot points 
style.use('seaborn')
plt.scatter(x, y, label = 'Data Points', alpha = 0.6, color = 'g', s = 75 )
plt.plot(x, regression_line, label = 'Best Fit Line', color = 'orange', linewidth = 4)
plt.xlabel('Number of Teams')
plt.ylabel('Number of Medals')
plt.legend()

# %%
#Display the cooefficients and intercept 
print(medals_Teams.coef_)
# Out:
# [0.74130302]

# %%
print(medals_DisciplineSport.intercept_)
# Out:
# 1.3510447512199182

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import geopandas as gpd 
#import plotly.express as px

# %%
world_df = pd.read_csv('WorldMap Coordinates.csv')
world_df.head()
# Out:
#              Country   Latitude   Longitude
# 0           Zimbabwe -19.015438   29.154857
# 1             Zambia -13.133897   27.849332
# 2              Yemen  15.552727   48.516388
# 3     Western Sahara  24.215527  -12.885834
# 4  Wallis and Futuna -13.768752 -177.156097

# %%
# using geopandas to convert long to lat to points 
geo_df = gpd.GeoDataFrame(world_df, Geometry = gpd.points_from_xy(world_df.longitude, world_df.latitude))
geo_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-5afcd8e459b4> in <module>
#       1 # using geopandas to convert long to lat to points
# ----> 2 geo_df = gpd.GeoDataFrame(world_df, Geometry = gpd.points_from_xy(world_df.longitude, world_df.latitude))
#       3 geo_df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'longitude'
